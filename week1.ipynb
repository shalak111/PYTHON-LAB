# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
a=10
b=20
print("a+b")
# Out:
# a+b

# %%
a=10
b=20
print(a-b)
# Out:
# -10

# %%
a=10
b=20
print(a*b)
# Out:
# 200

# %%
a=10
b=20
print(a/b)
# Out:
# 0.5
