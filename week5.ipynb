# %% [markdown]
# SET

# %%
print("===SET EXAMPLE===")
numbers={1,2,3,2,1}
print("set",numbers)
# Out:
# ===SET EXAMPLE===
# set {1, 2, 3}

# %%
numbers.add(4)
numbers.discard(2)

# %%
numbers={"1","2"}
numbers.add("4")
print(numbers)
# Out:
# {'4', '1', '2'}

# %%
numbers={"1","2","3"}
numbers.discard("3")
print(numbers)
# Out:
# {'2', '1'}

# %%
print("set",numbers)
# Out:
# set {'4', '1', '2'}

# %%
evens={2,4,6}
print("Union:",numbers|evens)
print("Intersection:",numbers & evens)
# Out:
# Union: {2, 4, '2', 6, '4', '1'}
# Intersection: set()

# %%
student = {
    "name": "Alice",
    "age":21,
    "Subjects": ["Maths","Physics"]
}
print("Dictionary:",student)
# Out:
# Dictionary: {'name': 'Alice', 'age': 21, 'Subjects': ['Maths', 'Physics']}

# %%
employee = {
    "id": 101,
    "name": "shalak",
    "age": 25,
    "department": "IT",
    "salary": 50000
}

print("Dictionary:",employee)
# Out:
# Dictionary: {'id': 101, 'name': 'shalak', 'age': 25, 'department': 'IT', 'salary': 50000}
