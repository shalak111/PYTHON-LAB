# %%
numbers=[12,45,67,23,89,34]
largest=max(numbers)
print("List",numbers)
print("Largest Element:",largest)
# Out:
# List [12, 45, 67, 23, 89, 34]
# Largest Element: 89

# %%
text="python"
frequency={}
for ch in text:
    if ch in frequency:
       frequency[ch]+=1
    else:
        frequency[ch]=1
print(frequency)
# Out:
# {'p': 1, 'y': 1, 't': 1, 'h': 1, 'o': 1, 'n': 1}

# %%
numbers=[10,20,30,20,40,10,50]
unique_numbers=list(set(numbers))
print("original list:",numbers)
print("unique List:",unique_numbers)
# Out:
# original list: [10, 20, 30, 20, 40, 10, 50]
# unique List: [40, 10, 50, 20, 30]

# %%
text="Engeenering"
reverse_text=text[::-1]
print("original string:",text)
print("Reversed string:",Reversed_text)
# Out:
# original string: Engeenering
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       2 reverse_text=text[::-1]
#       3 print("original string:",text)
# ----> 4 print("Reversed string:",Reversed_text)
#
# NameError: name 'Reversed_text' is not defined

# %%
dic1={"A":1,"B":2}
dict2={"C":3,"D":4}
merged_list=dict1|dict2
print("Dictionary 1:",dict1)
print("Dictionary 2:",dict2)
print("Merged Dictionay:",merged_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 dic1={"A":1,"B":2}
#       2 dict2={"C":3,"D":4}
# ----> 3 merged_list=dict1|dict2
#       4 print("Dictionary 1:",dict1)
#       5 print("Dictionary 2:",dict2)
#
# NameError: name 'dict1' is not defined

# %%
def greet():
    print("Hello,World!")
greet()
# Out:
# Hello,World!

# %%
def add(a,b):
    return a+b
print(add(3,5))
# Out:
# 8

# %%
def power(base,exp=2):
    return base **exp
print(power(4))
print(power(4,3))
# Out:
# 16
# 64
